# %%
import trivium
import grain128
import warnings


def main():
    # masukan string key dan vektor inisial
    key_str = "adrian"
    iv_str = "adrian"

    warnings.filterwarnings("ignore", category=UserWarning)

    data_params_trivium = [[key_str,iv_str,"Plainteks 1","plaintext1.txt","ciphertext_trivium/ciphertext1.txt","ciphertext_trivium/ciphertext_ascii1.txt"],[key_str,iv_str,"Plainteks 2","plaintext2.txt","ciphertext_trivium/ciphertext2.txt","ciphertext_trivium/ciphertext_ascii2.txt"],[key_str,iv_str,"Plainteks 3","plaintext3.txt","ciphertext_trivium/ciphertext3.txt","ciphertext_trivium/ciphertext_ascii3.txt"],[key_str,iv_str,"Plainteks 4","plaintext4.txt","ciphertext_trivium/ciphertext4.txt","ciphertext_trivium/ciphertext_ascii4.txt"],[key_str,iv_str,"Plainteks 5","plaintext5.txt","ciphertext_trivium/ciphertext5.txt","ciphertext_trivium/ciphertext_ascii5.txt"]]
    data_params_grain128 = [[key_str,"Plainteks 1","plaintext1.txt","ciphertext_grain128/ciphertext_grain1281.txt","ciphertext_grain128/ciphertext_grain128_ascii1.txt", "ciphertext_grain128/ciphertext_grain128_hex1.txt"],[key_str,"Plainteks 2","plaintext2.txt","ciphertext_grain128/ciphertext_grain1282.txt","ciphertext_grain128/ciphertext_grain128_ascii2.txt", "ciphertext_grain128/ciphertext_grain128_hex2.txt"],[key_str,"Plainteks 3","plaintext3.txt","ciphertext_grain128/ciphertext_grain1283.txt","ciphertext_grain128/ciphertext_grain128_ascii3.txt", "ciphertext_grain128/ciphertext_grain128_hex3.txt"],[key_str,"Plainteks 4","plaintext4.txt","ciphertext_grain128/ciphertext_grain1284.txt","ciphertext_grain128/ciphertext_grain128_ascii4.txt", "ciphertext_grain128/ciphertext_grain128_hex4.txt"],[key_str,"Plainteks 5","plaintext5.txt","ciphertext_grain128/ciphertext_grain1285.txt","ciphertext_grain128/ciphertext_grain128_ascii5.txt", "ciphertext_grain128/ciphertext_grain128_hex5.txt"]]
    print("======================================")
    print("========== TRIVIUM =================")
    for params in data_params_trivium:
        print("======================================")
        print(f"=========={params[2]}==============")
        trivium.visualize_text_trivium(*params)
        print(f"==========END {params[2]}==============")

    for params in data_params_grain128:
        print("======================================")
        print("========== GRAIN 128 =================")
        print("======================================")
        print(f"=========={params[1]}==============")
        grain128.visualize_text_grain128(*params)
        print(f"==========END {params[1]}==============")


if __name__ == '__main__':
    main()
# Out:
# ...
# ========== TRIVIUM =================
# ...
# ==========Plainteks 1==============
# Korelasi antara Plainteks 1 dan Ciphertext: 0.06469775795805213
# PSNR: 10.326216823340115
# ...
